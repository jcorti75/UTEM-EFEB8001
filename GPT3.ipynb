# %%
# %env OPENAI_API_KEY=key
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pip install  openai wandb
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.
# </div>

# %%
import os
import openai
import wandb

key="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"
openai.api_key = key
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
gpt_prompt = " necesito crear un resumen del siguiente texto: De pronto, como si un remolino hubiera echado raíces en el centro del pueblo, llegó la compañía bananera perseguida por la hojarasca. Era una hojarasca revuelta, alborotada, formada por los desperdicios humanos y materiales de los otros pueblos; rastrojos de una guerra civil que cada vez parecía más remota e inverosímil. La hojarasca era implacable. Todo lo contaminaba de su revuelto olor multitudinario, olor de secreción a flor de piel y de recóndita muerte. En menos de un año arrojó sobre el pueblo los escombros de numerosas catástrofes anteriores a ella misma, esparció en las calles su confusa carga de desperdicios. Y esos desperdicios, precipitadamente, al compás atolondrado e imprevisto de la tormenta, se iban seleccionando, individualizándose, hasta convertir lo que fue un callejón con un río en un extremo un corral para los muertos en el otro, en un pueblo diferente y complicado, hecho con los desperdicios de los otros pueblos. Allí vinieron, confundidos con la hojarasca humana, arrastrados por su impetuosa fuerza, los desperdicios de los almacenes, de los hospitales, de los salones de diversión, de las plantas eléctricas; desperdicios de mujeres solas y de hombres que amarraban la mula en un horcón del hotel, trayendo como un único equipaje un baúl de madera o un atadillo de ropa, y a los pocos meses tenían casa propia, dos concubinas y el título militar que les quedaron debiendo por haber llegado tarde a la guerra "

def prueba():
    response = openai.Completion.create(engine="text-davinci-003",prompt=gpt_prompt,temperature=0.5,max_tokens=2048,n=1,frequency_penalty=0.0,presence_penalty=0.0)
    return(response)

test=prueba()
print(test['choices'][0]['text'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#
# ...

# %%
### segunda pregunta
gpt_prompt = "Aquí hay un ejemplo de una clase en Python en 3 pasos:"


def respuesta():
    response_1 = openai.Completion.create(engine="text-davinci-003",prompt=gpt_prompt,temperature=0.5,max_tokens=1024,n=1)
    return(response_1)

evaluacion=respuesta()

print(evaluacion['choices'][0]['text'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#
# 1. Definir la clase:
#
# class MiClase:
#     pass
#
# 2. Agregar atributos a la clase:
#
# class MiClase:
#     atributo1 = &#39;valor1&#39;
#     atributo2 = &#39;valor2&#39;
#
# 3. Agregar métodos a la clase:
#
# class MiClase:
#     atributo1 = &#39;valor1&#39;
#     atributo2 = &#39;valor2&#39;
#
#     def metodo1(self):
#         print(&#39;Este es el método 1&#39;)
#
#     def metodo2(self):
#         print(&#39;Este es el método 2&#39;)
# </div>

# %%
### segunda pregunta
gpt_prompt = "necesito entender este segmento de codigo en python me lo puedes explicar??      pred1[i] == 1 and pred2[i] == 1:"


def respuesta():
    response_1 = openai.Completion.create(engine="text-davinci-003",prompt=gpt_prompt,temperature=0.5,max_tokens=2048,n=1)
    return(response_1)

evaluacion=respuesta()

print(evaluacion['choices'][0]['text'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
#
# Este segmento de código en Python se refiere a una condición lógica. Está comprobando si dos variables, pred1[i] y pred2[i], tienen el mismo valor, es decir, si ambas son iguales a 1. Si se cumple la condición, entonces se ejecutará el código que sigue a este segmento. Si no se cumple, entonces el código no se ejecutará.
# </div>

# %%
pip install flask
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.
# </div>

# %%
# from flask import Flask, jsonify
# import requests

# app = Flask(__name__)

# @app.route('/feriados', methods=['GET'])
# def feriados():
#     # Obtén los datos de los feriados de Chile desde una fuente externa
#     url = "https://apis.digital.gob.cl/fl/feriados/2020"
#     response = requests.get(url)
#     feriados = response.json()

#     # Devuelve la respuesta en formato JSON
#     return jsonify(feriados)

# if __name__ == '__main__':
#     app.run()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# from flask import Flask, jsonify
# import requests
# import datetime

# app = Flask(__name__)

# @app.route('/temperatura', methods=['GET'])
# def temperatura():
#     # Obtén los datos de la temperatura de Santiago de Chile desde una fuente externa
#     url = "https://api.openweathermap.org/data/2.5/forecast?q=Santiago,CL&appid={API_KEY}"
#     response = requests.get(url)
#     data = response.json()
    
#     # Obtén las temperaturas de hoy
#     today = datetime.datetime.now().strftime("%Y-%m-%d")
#     temperatures = [d['main']['temp'] for d in data['list'] if d['dt_txt'].startswith(today)]
    
#     # Calcula el promedio de las temperaturas
#     average_temp = sum(temperatures) / len(temperatures)
    
#     # Devuelve la respuesta en formato JSON
#     return jsonify(average_temp=average_temp)

# if __name__ == '__main__':
#     app.run()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pip install bs4
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.
# </div>

# %%
# import requests
# from bs4 import BeautifulSoup
# import datetime

# url = "https://www.macal.cl/autos/63674"

# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')

# vehiculos = []

# # Obtén los datos de cada vehículo en la página
# for vehiculo in soup.find_all('div', class_='aditem'):
#     marca_modelo = vehiculo.find('p', class_='title').text.strip()
#     precio = vehiculo.find('span', class_='price').text.strip()
#     fecha = datetime.datetime.now().strftime("%Y-%m-%d")
#     vehiculos.append({'marca_modelo': marca_modelo, 'precio': precio, 'fecha': fecha})

# # Imprime los resultados
# for v in vehiculos:
#     print(v)

# print (vehiculos)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# print (v)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd

# # hacer una solicitud a la página web
# url = "https://www.macal.cl/autos"
# response = requests.get(url)

# # analizar el HTML de la página
# soup = BeautifulSoup(response.text, 'html.parser')

# # buscar todos los elementos de la clase "card-item" que contienen información del auto
# cars = soup.find_all(class_='card-item')

# # crear una lista vacía para almacenar los datos
# data = []

# # extraer información de cada auto
# for car in cars:
#     brand = car.find(class_='brand').text
#     model = car.find(class_='model').text
#     date = car.find(class_='date').text
#     price = car.find(class_='Min').text
#     # agregar información extraída a la lista
#     data.append({'Marca': brand, 'Modelo': model, 'Fecha': date, 'Precio': price})

# # crear un dataframe con la información extraída
# df = pd.DataFrame(data)

# # Mostrar el dataframe
# print(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
