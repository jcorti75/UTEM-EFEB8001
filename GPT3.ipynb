# %%
key="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"

# %env OPENAI_API_KEY=key
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">env: OPENAI_API_KEY=key
# </div>

# %%
pip install  openai wandb
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Requirement already satisfied: openai in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (0.26.1)
# Requirement already satisfied: wandb in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (0.13.9)
# Requirement already satisfied: requests&gt;=2.20 in /databricks/python3/lib/python3.8/site-packages (from openai) (2.25.1)
# Requirement already satisfied: aiohttp in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from openai) (3.8.3)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.8/site-packages (from openai) (4.59.0)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from requests&gt;=2.20-&gt;openai) (1.26.14)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.20-&gt;openai) (2.10)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.20-&gt;openai) (2020.12.5)
# Requirement already satisfied: chardet&lt;5,&gt;=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.20-&gt;openai) (4.0.0)
# Requirement already satisfied: Click!=8.0.0,&gt;=7.0 in /databricks/python3/lib/python3.8/site-packages (from wandb) (7.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (52.0.0)
# Requirement already satisfied: sentry-sdk&gt;=1.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from wandb) (1.13.0)
# Requirement already satisfied: pathtools in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from wandb) (0.1.2)
# Requirement already satisfied: docker-pycreds&gt;=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: appdirs&gt;=1.4.3 in /usr/local/lib/python3.8/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.8/site-packages (from wandb) (3.7.4.3)
# Requirement already satisfied: PyYAML in /databricks/python3/lib/python3.8/site-packages (from wandb) (5.4.1)
# Requirement already satisfied: protobuf!=4.21.0,&lt;5,&gt;=3.12.0 in /databricks/python3/lib/python3.8/site-packages (from wandb) (3.17.2)
# Requirement already satisfied: GitPython&gt;=1.0.0 in /databricks/python3/lib/python3.8/site-packages (from wandb) (3.1.12)
# Requirement already satisfied: psutil&gt;=5.0.0 in /databricks/python3/lib/python3.8/site-packages (from wandb) (5.8.0)
# Requirement already satisfied: setproctitle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from wandb) (1.3.2)
# Requirement already satisfied: six&gt;=1.4.0 in /databricks/python3/lib/python3.8/site-packages (from docker-pycreds&gt;=0.4.0-&gt;wandb) (1.15.0)
# Requirement already satisfied: gitdb&lt;5,&gt;=4.0.1 in /databricks/python3/lib/python3.8/site-packages (from GitPython&gt;=1.0.0-&gt;wandb) (4.0.7)
# Requirement already satisfied: smmap&lt;5,&gt;=3.0.1 in /databricks/python3/lib/python3.8/site-packages (from gitdb&lt;5,&gt;=4.0.1-&gt;GitPython&gt;=1.0.0-&gt;wandb) (3.0.5)
# Requirement already satisfied: yarl&lt;2.0,&gt;=1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from aiohttp-&gt;openai) (1.8.2)
# Requirement already satisfied: async-timeout&lt;5.0,&gt;=4.0.0a3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from aiohttp-&gt;openai) (4.0.2)
# Requirement already satisfied: multidict&lt;7.0,&gt;=4.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from aiohttp-&gt;openai) (6.0.4)
# Requirement already satisfied: attrs&gt;=17.3.0 in /databricks/python3/lib/python3.8/site-packages (from aiohttp-&gt;openai) (20.3.0)
# Requirement already satisfied: aiosignal&gt;=1.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from aiohttp-&gt;openai) (1.3.1)
# Requirement already satisfied: frozenlist&gt;=1.1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from aiohttp-&gt;openai) (1.3.3)
# Requirement already satisfied: charset-normalizer&lt;3.0,&gt;=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-72cd6575-90d3-4c1c-88a2-5ccdc3a38ec8/lib/python3.8/site-packages (from aiohttp-&gt;openai) (2.1.1)
# Python interpreter will be restarted.
# </div>

# %%
import os
import openai
import wandb


openai.api_key = os.getenv("OPENAI_API_KEY")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
run = wandb.init(project='GPT-3 in Python')
prediction_table = wandb.Table(columns=["prompt", "completion"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&amp;B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: /usr/lib/python3.8/getpass.py:91: GetPassWarning: Can not control echo on the terminal.
#   passwd = fallback_getpass(prompt, stream)
# Warning: Password input may be echoed.
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
gpt_prompt = "what does it mean time series forecasting"


response = openai.Completion.create(
  engine="text-davinci-002",
  prompt=gpt_prompt,
  temperature=0.5,
  max_tokens=256,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0
)


print(response['choices'][0]['text'])


prediction_table.add_data(gpt_prompt,response['choices'][0]['text'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
